# %%
from FoodEmbedding import FoodEmbedding

embedding = FoodEmbedding()
# Out:
# c:\Users\micha\Documents\School\University\3rd Year\Final Year Project\Code\food_data_extraction\FoodEmbedding.py:17: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.food_nutrient = pd.concat([pd.read_csv(f"{os.path.join(base_dir, folder)}/food_nutrient.csv") for folder in folders], ignore_index = True)

# %%
import os

if os.path.exists("fdc_index.faiss") and os.path.exists("foods.parquet"):
    embedding.load(index_path = "fdc_index.faiss", food_path = "foods.parquet")
else:
    embedding.initialise()
    embedding.save()

# %%
result = embedding.search("Bibb lettuce")

# %%
first_id = result ["fdc_id"].iloc [0]

# %%
nutritional_info = embedding.get_nutritional_info(first_id)

# %%
nutritional_info [nutritional_info ["name"] == "Total Sugars"]
# Out:
#     nutrient_id  amount unit_name          name
# 27         2000    0.94         G  Total Sugars
