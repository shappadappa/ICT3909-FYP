# %% [markdown]
# # Food Embedding Testing Notebook

# %% [markdown]
# This notebook checks that the functionality of the `FoodEmbedding` is working as expected.

# %%
from FoodEmbedding import FoodEmbedding
import os

# %%
embedding = FoodEmbedding()
# Out:
# c:\Users\micha\Documents\School\University\3rd Year\Final Year Project\Code\food_data_extraction\FoodEmbedding.py:19: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.food_nutrient = pd.read_csv(f"{os.path.join(self.base_dir, 'FoodData_Central_csv_2025-12-18')}/food_nutrient.csv")

# %%
if os.path.exists("food_embedding.faiss"):
    embedding.load(index_path = "food_embedding.faiss")
else:
    embedding.initialise()
    embedding.save()

# %%
result = embedding.search("black pepper")

# %%
result
# Out:
#           fdc_id     data_type   description food_category_id  \
# 1522012  2157235  branded_food  BLACK PEPPER   Herbs & Spices
# 1136300  1721294  branded_food  BLACK PEPPER   Herbs & Spices
# 853546   1428997  branded_food  BLACK PEPPER   Herbs & Spices
# 515960   1039497  branded_food  BLACK PEPPER   Herbs & Spices
# 473147    946040  branded_food  BLACK PEPPER   Herbs & Spices
#
#         publication_date  score
# 1522012       2021-10-28    1.0
# 1136300       2021-03-19    1.0
# 853546        2021-02-26    1.0
# 515960        2020-06-26    1.0
# 473147        2020-05-28    1.0

# %%
first_id = result ["fdc_id"].iloc [0]

# %%
nutritional_info = embedding.get_nutritional_information(first_id)

# %%
nutritional_info
# Out:
#     nutrient_id  amount unit_name                            name
# 0          1162    0.00        MG  Vitamin C, total ascorbic acid
# 1          1258    0.00         G    Fatty acids, total saturated
# 2          1104    0.00        IU                   Vitamin A, IU
# 3          1253    0.00        MG                     Cholesterol
# 4          1257    0.00         G        Fatty acids, total trans
# 5          1004    0.00         G               Total lipid (fat)
# 6          1008    0.00      KCAL                          Energy
# 7          1089    0.00        MG                        Iron, Fe
# 8          1087    0.00        MG                     Calcium, Ca
# 9          1093    0.00        MG                      Sodium, Na
# 10         1079   41.70         G            Fiber, total dietary
# 11         2000    0.00         G                    Total Sugars
# 12         1003    0.00         G                         Protein
# 13         1005  166.67         G     Carbohydrate, by difference
