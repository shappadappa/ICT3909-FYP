# %% [markdown]
# # Food Embedding Testing Notebook

# %% [markdown]
# This notebook checks that the functionality of the `FoodEmbedding` is working as expected.

# %%
import os
import sys

sys.path.append("..")

from FoodEmbedding import FoodEmbedding

# %%
embedding = FoodEmbedding()
# Out:
# c:\Users\micha\Documents\School\University\3rd Year\Final Year Project\Code\food_data_extraction\FoodEmbedding.py:34: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.food_nutrient = pd.read_csv(

# %%
if os.path.exists("food_embedding.faiss"):
    embedding.load(index_path = "food_embedding.faiss")
else:
    embedding.initialise()
    embedding.save()

# %%
result = embedding.search("onions", top_n = 5)

# %%
result
# Out:
#           fdc_id          data_type            description  \
# 35373     170000     sr_legacy_food            Onions, raw
# 35381     170008     sr_legacy_food     Onions, sweet, raw
# 791002   1364112       branded_food                  ONION
# 744749   1313543       branded_food                  ONION
# 279128    570221       branded_food                  ONION
# ...          ...                ...                    ...
# 1124636  1709461       branded_food           PEARL ONIONS
# 1350683  1978302       branded_food           PEARL ONIONS
# 1063475  1645910       branded_food           PEARL ONIONS
# 2045316  2709953  survey_fndds_food  Onions, green, cooked
# 1264082  1889025       branded_food             SALT ONION
#
#                                         food_category_id publication_date  \
# 35373                                                 11       2019-04-01
# 35381                                                 11       2019-04-01
# 791002                              Other Cooking Sauces       2021-02-26
# 744749                                     Breads & Buns       2021-02-26
# 279128                              Other Cooking Sauces       2019-04-01
# ...                                                  ...              ...
# 1124636                                Frozen Vegetables       2021-03-19
# 1350683                                Frozen Vegetables       2021-07-29
# 1063475                                Frozen Vegetables       2021-03-19
# 2045316                                             6414       2024-10-31
# 1264082  Seasoning Mixes, Salts, Marinades & Tenderizers       2021-07-29
#
#             score
# 35373    0.809984
# 35381    0.775475
# 791002   0.892297
# 744749   0.892297
# 279128   0.892297
# ...           ...
# 1124636  0.789575
# 1350683  0.789575
# 1063475  0.789575
# 2045316  0.788457
# 1264082  0.787674
#
# [500 rows x 6 columns]

# %%
first_id = result ["fdc_id"].iloc [0]

# %%
nutritional_info = embedding.get_nutritional_information(first_id)

# %%
nutritional_info
# Out:
#      nutrient_id  amount unit_name                      name
# 0           1106   0.000        UG            Vitamin A, RAE
# 1           1257   0.000         G  Fatty acids, total trans
# 2           1104   2.000        IU             Vitamin A, IU
# 3           1178   0.000        UG              Vitamin B-12
# 4           1253   0.000        MG               Cholesterol
# ..           ...     ...       ...                       ...
# 113         1129   0.000        MG         Tocotrienol, beta
# 114         1325   0.000         G                 PUFA 20:3
# 115         1266   0.004         G                  SFA 18:0
# 116         1213   0.025         G                   Leucine
# 117         1198   0.100        MG                   Betaine
#
# [118 rows x 4 columns]

# %%
portion = embedding.get_portion_size(first_id)

# %%
portion
# Out:
# Empty DataFrame
# Columns: [id, fdc_id, seq_num, amount, measure_unit_id, portion_description, modifier, gram_weight, data_points, footnote, min_year_acquired]
# Index: []

# %%
print(first_id)
# Out:
# 170931
