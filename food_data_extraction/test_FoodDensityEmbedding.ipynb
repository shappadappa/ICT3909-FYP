# %%
from FoodDensityEmbedding import FoodDensityEmbedding

# %%
food_density_embedding = FoodDensityEmbedding()

# %%
# food_density_embedding.initialise()

import os

food_density_embedding.load(index_path = "food_density_embedding.faiss")

# %%
food_density_embedding.search("brown rice")
# Out:
#                  ingredient  volume (cm^3 or ml)  grams  density (g/cm^3)  \
# 44      Brown rice (cooked)              236.588  170.0          0.718549
# 45         Brown rice flour              236.588  128.0          0.541025
# 258  Rice (long grain, dry)              118.294   99.0          0.836898
#
#         score
# 44   0.875147
# 45   0.793482
# 258  0.749137

# %%
food_density_embedding.save()
